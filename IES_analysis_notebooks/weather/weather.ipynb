# %% [markdown]
# # weather

# %%
import pandas as pd

# %%
filename='MyWeather.txt'
df=pd.read_csv(filename,sep='\t',encoding = 'unicode_escape')
df.head()
# Out:
#     Unnamed: 0 Unnamed: 1 External dew-point temp. (°C)  \
# 0          NaN        NaN                           NaN
# 1         Date       Time                       KEW.FWT
# 2  Wed, 01/Jan      24:00                           NaN
# 3          NaN      01:00                          2.08
# 4          NaN      02:00                          2.22
#
#   Global radiation (W/m²) Max. adaptive temp. (°C)  \
# 0                     NaN                      NaN
# 1                 KEW.FWT                  KEW.FWT
# 2                     NaN                      NaN
# 3                   0.000                    23.02
# 4                   0.000                    23.02
#
#   Daily running mean temp. (°C) Direct radiation (W/m²)  \
# 0                           NaN                     NaN
# 1                       KEW.FWT                 KEW.FWT
# 2                           NaN                     NaN
# 3                          3.69                   0.000
# 4                          3.69                   0.000
#
#   Wet-bulb temperature (°C) Wind speed (m/s) Solar azimuth (deg.)  \
# 0                       NaN              NaN                  NaN
# 1                   KEW.FWT          KEW.FWT              KEW.FWT
# 2                       NaN              NaN                  NaN
# 3                      3.60             5.00                 25.7
# 4                      3.60             6.00                 48.8
#
#   Diffuse radiation (W/m²) Dry-bulb temperature (°C)
# 0                      NaN                       NaN
# 1                  KEW.FWT                   KEW.FWT
# 2                      NaN                       NaN
# 3                    0.000                      4.80
# 4                    0.000                      4.70

# %%
filename='MyWeather.txt'
df=pd.read_csv(filename,sep='\t',encoding = 'unicode_escape')
df=df.drop([0,1])
df['Unnamed: 0']=df['Unnamed: 0'].fillna(method='ffill')
df.head()
# Out:
#     Unnamed: 0 Unnamed: 1 External dew-point temp. (°C)  \
# 2  Wed, 01/Jan      24:00                           NaN
# 3  Wed, 01/Jan      01:00                          2.08
# 4  Wed, 01/Jan      02:00                          2.22
# 5  Wed, 01/Jan      03:00                          1.77
# 6  Wed, 01/Jan      04:00                          1.69
#
#   Global radiation (W/m²) Max. adaptive temp. (°C)  \
# 2                     NaN                      NaN
# 3                   0.000                    23.02
# 4                   0.000                    23.02
# 5                   0.000                    23.02
# 6                   0.000                    23.02
#
#   Daily running mean temp. (°C) Direct radiation (W/m²)  \
# 2                           NaN                     NaN
# 3                          3.69                   0.000
# 4                          3.69                   0.000
# 5                          3.69                   0.000
# 6                          3.69                   0.000
#
#   Wet-bulb temperature (°C) Wind speed (m/s) Solar azimuth (deg.)  \
# 2                       NaN              NaN                  NaN
# 3                      3.60             5.00                 25.7
# 4                      3.60             6.00                 48.8
# 5                      3.20             5.00                 66.5
# 6                      3.00             5.00                 80.6
#
#   Diffuse radiation (W/m²) Dry-bulb temperature (°C)
# 2                      NaN                       NaN
# 3                    0.000                      4.80
# 4                    0.000                      4.70
# 5                    0.000                      4.30
# 6                    0.000                      4.00

# %%
filename='MyWeather.txt'
df=pd.read_csv(filename,sep='\t',encoding = 'unicode_escape')
df=df.drop([0,1])
df['Unnamed: 0']=df['Unnamed: 0'].fillna(method='ffill')
df['Unnamed: 0']=df['Unnamed: 0'].str[5:] + r'/2003'
df.head()
# Out:
#     Unnamed: 0 Unnamed: 1 External dew-point temp. (°C)  \
# 2  01/Jan/2003      24:00                           NaN
# 3  01/Jan/2003      01:00                          2.08
# 4  01/Jan/2003      02:00                          2.22
# 5  01/Jan/2003      03:00                          1.77
# 6  01/Jan/2003      04:00                          1.69
#
#   Global radiation (W/m²) Max. adaptive temp. (°C)  \
# 2                     NaN                      NaN
# 3                   0.000                    23.02
# 4                   0.000                    23.02
# 5                   0.000                    23.02
# 6                   0.000                    23.02
#
#   Daily running mean temp. (°C) Direct radiation (W/m²)  \
# 2                           NaN                     NaN
# 3                          3.69                   0.000
# 4                          3.69                   0.000
# 5                          3.69                   0.000
# 6                          3.69                   0.000
#
#   Wet-bulb temperature (°C) Wind speed (m/s) Solar azimuth (deg.)  \
# 2                       NaN              NaN                  NaN
# 3                      3.60             5.00                 25.7
# 4                      3.60             6.00                 48.8
# 5                      3.20             5.00                 66.5
# 6                      3.00             5.00                 80.6
#
#   Diffuse radiation (W/m²) Dry-bulb temperature (°C)
# 2                      NaN                       NaN
# 3                    0.000                      4.80
# 4                    0.000                      4.70
# 5                    0.000                      4.30
# 6                    0.000                      4.00

# %%
filename='MyWeather.txt'
df=pd.read_csv(filename,sep='\t',encoding = 'unicode_escape')
df=df.drop([0,1])
df['Unnamed: 0']=df['Unnamed: 0'].fillna(method='ffill')
df['Unnamed: 0']=df['Unnamed: 0'].str[5:] + r'/2003'
mask=(df['Unnamed: 1']=='24:00')
df['Unnamed: 1'][mask]='00:00'
df.head()
# Out:
#     Unnamed: 0 Unnamed: 1 External dew-point temp. (°C)  \
# 2  01/Jan/2003      00:00                           NaN
# 3  01/Jan/2003      01:00                          2.08
# 4  01/Jan/2003      02:00                          2.22
# 5  01/Jan/2003      03:00                          1.77
# 6  01/Jan/2003      04:00                          1.69
#
#   Global radiation (W/m²) Max. adaptive temp. (°C)  \
# 2                     NaN                      NaN
# 3                   0.000                    23.02
# 4                   0.000                    23.02
# 5                   0.000                    23.02
# 6                   0.000                    23.02
#
#   Daily running mean temp. (°C) Direct radiation (W/m²)  \
# 2                           NaN                     NaN
# 3                          3.69                   0.000
# 4                          3.69                   0.000
# 5                          3.69                   0.000
# 6                          3.69                   0.000
#
#   Wet-bulb temperature (°C) Wind speed (m/s) Solar azimuth (deg.)  \
# 2                       NaN              NaN                  NaN
# 3                      3.60             5.00                 25.7
# 4                      3.60             6.00                 48.8
# 5                      3.20             5.00                 66.5
# 6                      3.00             5.00                 80.6
#
#   Diffuse radiation (W/m²) Dry-bulb temperature (°C)
# 2                      NaN                       NaN
# 3                    0.000                      4.80
# 4                    0.000                      4.70
# 5                    0.000                      4.30
# 6                    0.000                      4.00

# %%
filename='MyWeather.txt'
df=pd.read_csv(filename,sep='\t',encoding = 'unicode_escape')
df=df.drop([0,1])
df['Unnamed: 0']=df['Unnamed: 0'].fillna(method='ffill')
df['Unnamed: 0']=df['Unnamed: 0'].str[5:] + r'/2003'
mask=(df['Unnamed: 1']=='24:00')
df['Unnamed: 1'][mask]='00:00'
df['Unnamed: 1']=df['Unnamed: 1'].str[:3]+'30'
df.head()
# Out:
#     Unnamed: 0 Unnamed: 1 External dew-point temp. (°C)  \
# 2  01/Jan/2003      00:30                           NaN
# 3  01/Jan/2003      01:30                          2.08
# 4  01/Jan/2003      02:30                          2.22
# 5  01/Jan/2003      03:30                          1.77
# 6  01/Jan/2003      04:30                          1.69
#
#   Global radiation (W/m²) Max. adaptive temp. (°C)  \
# 2                     NaN                      NaN
# 3                   0.000                    23.02
# 4                   0.000                    23.02
# 5                   0.000                    23.02
# 6                   0.000                    23.02
#
#   Daily running mean temp. (°C) Direct radiation (W/m²)  \
# 2                           NaN                     NaN
# 3                          3.69                   0.000
# 4                          3.69                   0.000
# 5                          3.69                   0.000
# 6                          3.69                   0.000
#
#   Wet-bulb temperature (°C) Wind speed (m/s) Solar azimuth (deg.)  \
# 2                       NaN              NaN                  NaN
# 3                      3.60             5.00                 25.7
# 4                      3.60             6.00                 48.8
# 5                      3.20             5.00                 66.5
# 6                      3.00             5.00                 80.6
#
#   Diffuse radiation (W/m²) Dry-bulb temperature (°C)
# 2                      NaN                       NaN
# 3                    0.000                      4.80
# 4                    0.000                      4.70
# 5                    0.000                      4.30
# 6                    0.000                      4.00

# %%
filename='MyWeather.txt'
df=pd.read_csv(filename,sep='\t',encoding = 'unicode_escape')
df=df.drop([0,1])
df['Unnamed: 0']=df['Unnamed: 0'].fillna(method='ffill')
df['Unnamed: 0']=df['Unnamed: 0'].str[5:] + r'/2003'
mask=(df['Unnamed: 1']=='24:00')
df['Unnamed: 1'][mask]='00:00'
df['Unnamed: 1']=df['Unnamed: 1'].str[:3]+'30'
df.insert(0,column='datetime',value=pd.to_datetime(df['Unnamed: 0']+' '+df['Unnamed: 1'],format='%d/%b/%Y %H:%M'))
df=df.drop(columns=['Unnamed: 0','Unnamed: 1'])
df=df.set_index('datetime')
df.to_csv(filename+'.csv')
df.head()
# Out:
#                     External dew-point temp. (°C) Global radiation (W/m²)  \
# datetime
# 2003-01-01 00:30:00                           NaN                     NaN
# 2003-01-01 01:30:00                          2.08                   0.000
# 2003-01-01 02:30:00                          2.22                   0.000
# 2003-01-01 03:30:00                          1.77                   0.000
# 2003-01-01 04:30:00                          1.69                   0.000
#
#                     Max. adaptive temp. (°C) Daily running mean temp. (°C)  \
# datetime
# 2003-01-01 00:30:00                      NaN                           NaN
# 2003-01-01 01:30:00                    23.02                          3.69
# 2003-01-01 02:30:00                    23.02                          3.69
# 2003-01-01 03:30:00                    23.02                          3.69
# 2003-01-01 04:30:00                    23.02                          3.69
#
#                     Direct radiation (W/m²) Wet-bulb temperature (°C)  \
# datetime
# 2003-01-01 00:30:00                     NaN                       NaN
# 2003-01-01 01:30:00                   0.000                      3.60
# 2003-01-01 02:30:00                   0.000                      3.60
# 2003-01-01 03:30:00                   0.000                      3.20
# 2003-01-01 04:30:00                   0.000                      3.00
#
#                     Wind speed (m/s) Solar azimuth (deg.)  \
# datetime
# 2003-01-01 00:30:00              NaN                  NaN
# 2003-01-01 01:30:00             5.00                 25.7
# 2003-01-01 02:30:00             6.00                 48.8
# 2003-01-01 03:30:00             5.00                 66.5
# 2003-01-01 04:30:00             5.00                 80.6
#
#                     Diffuse radiation (W/m²) Dry-bulb temperature (°C)
# datetime
# 2003-01-01 00:30:00                      NaN                       NaN
# 2003-01-01 01:30:00                    0.000                      4.80
# 2003-01-01 02:30:00                    0.000                      4.70
# 2003-01-01 03:30:00                    0.000                      4.30
# 2003-01-01 04:30:00                    0.000                      4.00

# %%
df.columns
# Out:
# Index(['datetime', 'External dew-point temp. (°C)', 'Global radiation (W/m²)',
#        'Max. adaptive temp. (°C)', 'Daily running mean temp. (°C)',
#        'Direct radiation (W/m²)', 'Wet-bulb temperature (°C)',
#        'Wind speed (m/s)', 'Solar azimuth (deg.)', 'Diffuse radiation (W/m²)',
#        'Dry-bulb temperature (°C)'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,figsize=(12,4))
ax.plot(df['Dry-bulb temperature (°C)'])
ax.set_xlabel('Date')
ax.set_ylabel('Dry-bulb temperature (°C)')
plt.show()

# %%
df[1:].plot()
